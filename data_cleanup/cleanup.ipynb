# %% [markdown]
# # Tracking Data Clean Up Notebook

# %% [markdown]
# **Imports**

# %%
from lib.match import Match

# %% [markdown]
# **Tracking Data Import**

# %%
PATH = "./../track/output/"
FILE_NAME = "sample_30.mov.csv"

# %%
match = Match()
match.import_metrica(PATH, FILE_NAME)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 match = Match()
# ----> 2 match.import_metrica(PATH, FILE_NAME)
#
# File ~/Bremen/FootballTrackingDataGeneration-main/data_cleanup/lib/match.py:56, in Match.import_metrica(self, file_path, file_name)
#      51 for i in range(3, len(frame), 2):
#      52     frame_data = {
#      53         "frame" : frame[1],
#      54         "time" : frame[2]
#      55     }
# ---> 56     if frame[i] == "0" or frame[i+1] == "0":
#      57         frame_data["empty"] = True
#      58     else:
#
# IndexError: list index out of range

# %% [markdown]
# **Data Cleaning**

# %%
ball = match.ball
ball.clean_path()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 ball = match.ball
# ----> 2 ball.clean_path()
#
# File ~/Bremen/FootballTrackingDataGeneration-main/data_cleanup/lib/ball.py:92, in Ball.clean_path(self)
#      89         self.replace_frame(int(frame_number), empty_frame)
#      91 self.fill_gaps()
# ---> 92 self.remove_arcs()
#
# File ~/Bremen/FootballTrackingDataGeneration-main/data_cleanup/lib/ball.py:164, in Ball.remove_arcs(self)
#     162 def remove_arcs(self):
#     163     path = self.path()
# --> 164     coordinates = remove_arcs_from_path(path)
#     166     for frame_number in range(1, len(coordinates)):
#     167         frame = self.frame(frame_number)
#
# File ~/Bremen/FootballTrackingDataGeneration-main/data_cleanup/lib/utils.py:77, in remove_arcs_from_path(coordinates)
#      74 Xraw = path_raw.copy()
# ...

# %% [markdown]
# **Exoprt Data**

# %% [markdown]
# match.export()
